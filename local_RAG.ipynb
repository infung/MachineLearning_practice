# %% [markdown]
# <a href="https://colab.research.google.com/github/infung/MachineLearning_practice/blob/main/local_RAG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install -U langchain openai chromadb langchain-experimental # (newest versions required for multi-modal)
! pip install "unstructured[all-docs]" pillow pydantic lxml pillow matplotlib chromadb tiktoken
! pip install sentence-transformers transformers huggingface_hub einops rank_bm25
! pip install -U FlagEmbedding
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 975.5/975.5 kB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.5/327.5 kB 12.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 559.5/559.5 kB 15.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 202.7/202.7 kB 14.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.8/332.8 kB 18.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.4/127.4 kB 18.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 12.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 24.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 13.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 9.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 6.4 MB/s eta 0:00:00
# ...

# %%
# !apt-get install poppler-utils
# !apt-get install -y tesseract-ocr
# !apt-get install -y libtesseract-dev
# !apt-get install -y tesseract-ocr-eng
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# poppler-utils is already the newest version (22.02.0-2ubuntu0.4).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 45 not upgraded.
# Need to get 4,816 kB of archives.
# After this operation, 15.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-eng all 1:4.00~git30-7274cfa-1.1 [1,591 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-osd all 1:4.00~git30-7274cfa-1.1 [2,990 kB]
# ...

# %% [markdown]
# **SET UP Ollama**

# %%
# !pip install colab-xterm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.6/115.6 kB 3.5 MB/s eta 0:00:00
# ...

# %%
# curl https://ollama.ai/install.sh | sh
# ollama serve & ollama pull ollama3

# %%
# %load_ext colabxterm
# %xterm
# Out:
# Launching Xterm...

# %% [markdown]
# **Test Ollama**

# %%
from langchain_community.chat_models import ChatOllama
from langchain_core.messages import HumanMessage

llm = ChatOllama(
    temperature=0,
    model='llama3',
    streaming=True,
    top_k=50,
    # A higher value (100) will give more diverse answers, while a lower value (10) will be more conservative.
    top_p=0.3,
    # Higher value (0.95) will lead to more diverse text, while a lower value (0.5) will generate more
    # focused text.
)

messages = [
    HumanMessage(
        content="What color is the sky at different times of the day? Respond using JSON"
    )
]

chat_model_response = llm.invoke(messages)
print(chat_model_response)
# Out:
# ---------------------------------------------------------------------------
# OllamaEndpointNotFoundError               Traceback (most recent call last)
# <ipython-input-5-64c0d72c5ff8> in <cell line: 21>()
#      19 ]
#      20
# ---> 21 chat_model_response = llm.invoke(messages)
#      22 print(chat_model_response)
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py in invoke(self, input, config, stop, **kwargs)
#     246         return cast(
#     247             ChatGeneration,
# --> 248             self.generate_prompt(
#     249                 [self._convert_input(input)],
#     250                 stop=stop,
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/language_models/chat_models.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     675     ) -> LLMResult:
#     676         prompt_messages = [p.to_messages() for p in prompts]
# ...

# %%
import time
from langchain.embeddings import HuggingFaceEmbeddings

# function for loading the embedding model
def load_embedding_model(model_name):
    print("Loading embedding model...")
    start_time = time.time()
    hugging_face_embeddings = HuggingFaceEmbeddings(
        model_name=model_name,
        model_kwargs={'device': 'cuda:0'},
    )
    end_time = time.time()
    time_taken = round(end_time - start_time, 2)
    print(f"Embedding model load time: {time_taken} seconds.\n")
    return hugging_face_embeddings

# %% [markdown]
# **DATA EXTRACTION**

# %%
import os

tessdata_prefix = '/usr/share/tesseract-ocr/4.00/tessdata/'
os.environ['TESSDATA_PREFIX'] = tessdata_prefix

# %%
from langchain_text_splitters import CharacterTextSplitter
from unstructured.partition.pdf import partition_pdf
from unstructured.documents.elements import Table, CompositeElement
import pytesseract

#  chunk_size = [128, 256, 512, 1024, 2048]

# Extract elements from PDF
def extract_pdf_elements(path, fname):
    """
    Extract images, tables, and chunk text from a PDF file.
    path: File path, which is used to dump images (.jpg)
    fname: File name
    """
    image_output_path = os.path.join(path, "images")

    # Create the directory if it does not exist
    if not os.path.exists(image_output_path):
        os.makedirs(image_output_path)
    pdf_filepath = os.path.join(path, fname)
    return partition_pdf(
        filename=pdf_filepath,
        extract_images_in_pdf=True,
        infer_table_structure=True,
        chunking_strategy="by_title",
        max_characters=512, # 1024: optimal chunk size according to https://www.llamaindex.ai/blog/evaluating-the-ideal-chunk-size-for-a-rag-system-using-llamaindex-6207e5d3fec5
        new_after_n_chars=3800,
        combine_text_under_n_chars=200,
        image_output_dir_path=image_output_path,
    )


# Categorize elements by type
def categorize_elements(raw_pdf_elements):
    """
    Categorize extracted elements from a PDF into tables and texts.
    raw_pdf_elements: List of unstructured.documents.elements
    """
    tables = []
    texts = []
    for element in raw_pdf_elements:
        if "unstructured.documents.elements.Table" in str(type(element)):
                tables.append(element)
        elif "unstructured.documents.elements.CompositeElement" in str(type(element)):
                texts.append(str(element))
    return texts, tables

# %% [markdown]
# **DATA CLEANING**

# %%
import re
from unstructured.documents.elements import Text
from unstructured.cleaners.core import replace_unicode_quotes
from unstructured.cleaners.core import clean
from unstructured.cleaners.core import clean_non_ascii_chars

def remove_links(text):
    """
    Remove all links from the given text.

    Args:
    text (str): The input text from which links need to be removed.

    Returns:
    str: The text with all links removed.
    """
    # Regular expression pattern to match URLs
    url_pattern = re.compile(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')

    # Substitute matched URLs with an empty string
    cleaned_text = re.sub(url_pattern, '', text)

    return cleaned_text

def contains_link(text):
    """
    Check if the given text contains any links.

    Args:
    text (str): The input text to check for links.

    Returns:
    bool: True if the text contains at least one link, False otherwise.
    """
    # Regular expression pattern to match URLs
    url_pattern = re.compile(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')

    # Search for URLs in the text
    if re.search(url_pattern, text):
        return True
    else:
        return False


def clean_text(texts):
    texts = [replace_unicode_quotes(text) for text in texts]
    texts = [remove_links(text) for text in texts]
    texts = [clean(text, bullets=True, lowercase=True,extra_whitespace=True, dashes=True) for text in texts]
    texts = [clean_non_ascii_chars(text) for text in texts]
    return texts

# %% [markdown]
# # **EXTRACT DATA AND GENERATE SUMMARIES**

# %% [markdown]
# **Text and Table Summaries**

# %%
from langchain_community.chat_models import ChatOllama
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts.prompt import PromptTemplate
# Prompt
# prompt_text = """Please rephrase the following text to improve its readability without adding any additional word.Please directly output the rephrased sentence: {element}"""
prompt_text = """
    You are an assistant tasked with summarizing tables .
    These summaries will be embedded and used to retrieve the raw text or table elements.
    Give a concise summary of the table or text that is well optimized for retrieval.
    Do not start your response with "Here is a concise summary of the content provided:". Instead, provide a summary directly.
    Table or text: {element} """
prompt = PromptTemplate.from_template(prompt_text)

# Summary chain
model = ChatOllama(model="llama3")
summarize_chain = {"element": lambda x: x} | prompt | model | StrOutputParser()

# Specify the path to your PDF file
folderpath= "./"
result = {
    "PDF": [],
    "context": [],
    "table":[]
}
pdf_id = 1


table_summaries_results=[]
tables_results = []
texts_result = []
for filename in os.listdir(folderpath):
    if filename.endswith(".pdf"):
        print('processing pdf: ', filename)

        result["PDF"].append({
            "pdf_id": pdf_id,
            "path": filename
        })
        # Get elements
        raw_pdf_elements = extract_pdf_elements(folderpath, filename)
        # Get text, tables
        texts, tables = categorize_elements(raw_pdf_elements)
        texts = clean_text(texts)
        # # Optional: Enforce a specific token size for texts
        for text in texts:
            texts_result.append(text)
            result["context"].append({
                "id": len(result["context"]) + 1,
                "pdf_id": pdf_id,
                "content": text
            })

        for table in tables:
            tables_results.append(table.to_dict()['metadata']['text_as_html'])
            result["table"].append({
                "id": len(result["table"]) + 1,
                "html": table.to_dict()['metadata']['text_as_html'],
                "summary": ""  # Provide a summary or remove this field
            })
        str_tables = [str(table) for table in tables]
        # Apply to tables
        table_summaries = summarize_chain.batch(str_tables, {"max_concurrency": 5})
        table_summaries_results.append(table_summaries)

        pdf_id += 1
# Out:
# processing pdf:  2023 Zhang et al. (AiC) VR for crane-lift training.pdf
# processing pdf:  2021 Zhang and Pan (AiC) VR TCLP MiC.pdf
# processing pdf:  2022 Zhu et al. (AiC) AI-based crane-lift path planning.pdf
# processing pdf:  2024 Zhu et al. (AEI) Developing a fast and accurate collision detection strategy for MiC lifting.pdf
# processing pdf:  2024 Wong-et-al (JCEM) multiuser-virtual-reality-enabled-collaborative-heavy-lift-planning-in-construction.pdf
# processing pdf:  2021 Zhang et al (ECAM) Critical Considerations on TCLP for MiC.pdf
# processing pdf:  2021 Zhang and Pan (AiC) MCDA for TCLP.pdf

# %%
tables_summaries = sum(table_summaries_results,[]) # merging into one list
for summary, table in zip(table_summaries, result["table"]): # assign each table summary to result['table']
    table['summary'] = summary

# %%
print(len(tables_summaries), len(tables_results), len(texts_result))
print(result.keys())
# Out:
# 62 62 499
# dict_keys(['PDF', 'context', 'table'])

# %%
tables_summaries[:2]
# Out:
# ['The roles discussed are Rigger and Crane Operator, with major duties including warning personnel of lifting operations, ensuring safe working loads, and monitoring lifting zones. The Rigger is responsible for standardized communication with the Crane Operator using hand signals and walkie-talkies, while the Crane Operator must examine wire ropes, ensure balanced loads, and operate smoothly to avoid sudden movements.',
#  'Summary: Average scores for memory tests across different groups and time intervals. The groups include A&B (Handbook), C&D (VR system), and E&F (combined Handbook + VR). Results show varying average scores ranging from 60 to 85, with the highest scores achieved by Groups E&F at 80-85.']

# %%
tables_results[:2]
# Out:
# ['<table><thead><tr><th>Roles</th><th>Major duties</th></tr></thead><tbody><tr><td rowspan="7">Signaler</td><td>Warn irrelevant personnel to leave before lifting operation</td></tr><tr><td>Ensure the loads do not exceed the safe working load Ensure the lifting zone has been properly fenced off with barriers</td></tr><tr><td>before lifting Ensure there is no rigger on the object being lifted before starting</td></tr><tr><td>the operation * Communication with crane operator using standardized hand</td></tr><tr><td>signals and walkie-talkies Warn the crane operator when the crane is approaching the</td></tr><tr><td>overlapping zone</td></tr><tr><td>Monitor the lifting operation to avoid passing over any person Monitor wind factor and inform the operator to suspend lifting if needed *</td></tr><tr><td rowspan="4">Rigger</td><td>Place and store tools in an orderly manner to avoid fall of tools from heights</td></tr><tr><td>Wear safety belt secured to an anchorage point when securing a loa
# ...

# %%
texts_result[:2]
# Out:
# ['automation in construction 150 (2023) 104848 elsevier contents lists available at sciencedirect automation in construction automation in construction journal homepage: www.elsevier.com/locate/autcon virtual reality enhanced multi role collaboration in crane lift training for modular construction | check for zhiqian zhang a, mun on wong b, wei pan c, * a department of civil engineering, the university of hong kong, china b department of civil and environmental engineering, university of macau, china c department of civil engineering, the university of hong kong, hong kong sar, china',
# ...

# %% [markdown]
# **Image Summaries**

# %%
import base64
import os

from langchain_core.messages import HumanMessage


def encode_image(image_path):
    """Getting the base64 string"""
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode("utf-8")


def prompt_func(data):
    img_base64 = data["image"]
    prompt = data["text"]

    image_part = {
        "type": "image_url",
        "image_url": f"data:image/jpeg;base64,{img_base64}",
    }

    content_parts = []

    text_part = {"type": "text", "text": prompt}

    content_parts.append(image_part)
    content_parts.append(text_part)

    return [HumanMessage(content=content_parts)]


def image_summarize(img_base64, prompt):
    """Make image summary"""
    llm = ChatOllama(model="bakllava", temperature=0)
    chain = prompt_func | llm | StrOutputParser()

    query_chain = chain.invoke(
        {"text": prompt, "image": img_base64}
    )

    return query_chain


def generate_img_summaries(path):
    """
    Generate summaries and base64 encoded strings for images
    path: Path to list of .jpg files extracted by Unstructured
    """

    # Store base64 encoded images
    img_base64_list = []

    # Store image summaries
    image_summaries = []

    # Prompt
    prompt = """You are an assistant tasked with summarizing images for retrieval. \
    These summaries will be embedded and used to retrieve the raw image. \
    Give a concise summary of the image that is well optimized for retrieval."""

    # Apply to images
    for img_file in sorted(os.listdir(path)):
        if img_file.endswith(".jpg"):
            img_path = os.path.join(path, img_file)
            base64_image = encode_image(img_path)
            img_base64_list.append(base64_image)
            image_summaries.append(image_summarize(base64_image, prompt))

    return img_base64_list, image_summaries

fpath = "./figures"
# Image summaries
img_base64_list, images_summaries = generate_img_summaries(fpath)

# %%
image_extraction = []
for img_base64, image_summary in zip(img_base64_list, images_summaries):
    image_extraction.append({
                "base64": img_base64,
                "summary": image_summary
            })

# %%
print(len(images_summaries))
images_summaries[:5]
# Out:
# 92
# ['\nA tree with a man and a woman standing next to it. The man is holding onto the tree while the woman is looking up at the branches. There are also some books nearby, suggesting that this scene might be related to knowledge or research.',
#  ' An international peer-reviewed research journal focusing on construction technology, design and engineering, construction management and maintenance, and materials and management.',
#  ' A red and white circle with a check for updates inside of it.',
#  '3D graph showing projections on a 2D plane.',
#  '\nA building with a yellow frame and a blue sky.']

# %%
img_base64_list[:5]
# Out:
# ['...',
#  '...',
#  '...',
#  '...',
#  '...']

# %% [markdown]
# # **DB - Add to vectorstore**

# %% [markdown]
# **Embedding Models**

# %%
from transformers import AutoModel

# Load the Embedding Model
all_mini = load_embedding_model('all-MiniLM-L6-v2')
multi_qa_mini = load_embedding_model("multi-qa-MiniLM-L6-dot-v1")
all_mpnet = load_embedding_model('all-mpnet-base-v2')
# Out:
# Loading embedding model...
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Embedding model load time: 1.14 seconds.
#
# Loading embedding model...
# Embedding model load time: 1.14 seconds.
#
# Loading embedding model...
# Embedding model load time: 1.17 seconds.

# %% [markdown]
# # **Query Enhancement**

# %% [markdown]
# Wang Ding Rui please add your code here

# %% [markdown]
# # **Agentic Routing**

# %% [markdown]
# Need to do purpose detection:
# - What type of data needed?
# -- Images? Texts? Tables?
# - Does the query ask for data from different documents?
# -- Check metadata and do filtering? (metadata -> extraction_pdfname.jsonl)
# -- ???
# - What's more???

# %% [markdown]
# # **Multi-way Retrieve/Recall**

# %% [markdown]
# - Sparse Retriever: (Term-based similarity)
# -- BM25 (Best Matching 25)
# - Dense Retriever: (Semantic similarity)
# -- Embedding-based Models / Vector Similarity

# %%
import uuid

from langchain.retrievers import (
    MergerRetriever,
    MultiVectorRetriever,
    ContextualCompressionRetriever,
    BM25Retriever,
    EnsembleRetriever
)
from langchain.retrievers.document_compressors import DocumentCompressorPipeline

from langchain_community.document_transformers import (
    EmbeddingsClusteringFilter,
    EmbeddingsRedundantFilter,
)
from langchain.storage import InMemoryStore
from langchain_community.vectorstores import Chroma
from langchain_core.documents import Document

K = 10 # top k

def create_multi_vector_retriever(
    vectorstore, text_summaries, texts, table_summaries, tables, image_summaries, images
):
    """
    Create retriever that indexes summaries, but returns raw images or texts
    """

    # Initialize the storage layer
    store = InMemoryStore()
    id_key = "doc_id"

    # Create the multi-vector retriever
    retriever = MultiVectorRetriever(
        vectorstore=vectorstore,
        docstore=store,
        id_key=id_key,
    )

    def add_documents(retriever, doc_summaries, doc_contents):
        doc_ids = [str(uuid.uuid4()) for _ in doc_contents]
        summary_docs = [
            Document(page_content=s, metadata={id_key: doc_ids[i]})
            for i, s in enumerate(doc_summaries)
        ]
        retriever.vectorstore.add_documents(summary_docs)
        retriever.docstore.mset(list(zip(doc_ids, doc_contents)))

    # Add texts, tables, and images
    # Check that text_summaries is not empty before adding
    if text_summaries:
        add_documents(retriever, text_summaries, texts)
    # Check that table_summaries is not empty before adding
    if table_summaries:
        add_documents(retriever, table_summaries, tables)
    # Check that image_summaries is not empty before adding
    if image_summaries:
        add_documents(retriever, image_summaries, images)

    return retriever

# %% [markdown]
# **Multivector Retriever** that combines with:
# - all_mini embedding with similarity search (dense)
# - multi_qa_mini embedding with maximal marginal relevance (dense)
# - BM25 (sparse)

# %%
from langchain.retrievers.multi_vector import SearchType

# Embedding retriever that uses similarity search
all_mini_vectorstore = Chroma(
    collection_name="all_mini", embedding_function=all_mini
)

all_mini_multi_retreiver = create_multi_vector_retriever(
    vectorstore=all_mini_vectorstore,
    text_summaries=texts_result,  # list of text chunk, 1024 small enough, no need summaries
    texts=texts_result,   # list of text chunk
    table_summaries=tables_summaries,   # list of table summaries
    tables=tables_results,   # list of table dataform
    image_summaries=images_summaries,   # list of image summaries
    images=img_base64_list,    # list of base64 image byte
)
all_mini_multi_retreiver.search_type = SearchType.similarity
all_mini_multi_retreiver.k = K

# Embedding retriever that uses mmr
multi_qa_mini_vectorstore = Chroma(
    collection_name="multi_qa_mini", embedding_function=multi_qa_mini
)

multi_qa_mini_multi_retreiver = create_multi_vector_retriever(
    vectorstore=multi_qa_mini_vectorstore,
    text_summaries=texts_result,  # list of text chunk, 1024 small enough, no need summaries
    texts=texts_result,   # list of text chunk
    table_summaries=tables_summaries,   # list of table summaries
    tables=tables_results,   # list of table dataform
    image_summaries=images_summaries,   # list of image summaries
    images=img_base64_list,    # list of base64 image byte
)
multi_qa_mini_multi_retreiver.search_type = SearchType.mmr
multi_qa_mini_multi_retreiver.k = K

# %%
# testing
query = "What is the definition and purpose of Microcode Instruction Cache (MiC) in the context of CPU architecture? Please provide detailed information about its functionality, advantages, and potential applications. If possible, consider providing specific examples or use cases to illustrate its significance."
docs = all_mini_multi_retreiver.get_relevant_documents(query)
docs
# Out:
# []

# %%
# testing
query = "What is the definition and purpose of Microcode Instruction Cache (MiC) in the context of CPU architecture? Please provide detailed information about its functionality, advantages, and potential applications. If possible, consider providing specific examples or use cases to illustrate its significance."
docs = multi_qa_mini_multi_retreiver.get_relevant_documents(query)
docs
# Out:
# []

# %%
# BM25 retriever
metadatas = [{'source': 2, 'doc_id': str(uuid.uuid4())} for _ in texts_result]

bm25_retreiver = BM25Retriever.from_texts(texts_result, metadatas=metadatas)

bm25_retreiver.k = K  # retrieve the top k results

# %%
# testing
query = "What is the definition and purpose of Microcode Instruction Cache (MiC) in the context of CPU architecture? Please provide detailed information about its functionality, advantages, and potential applications. If possible, consider providing specific examples or use cases to illustrate its significance."
docs = bm25_retreiver.get_relevant_documents(query)
docs
# Out:
# [Document(page_content='system development of co help the questionnaire was designed by referring to the information technology measurement framework (andresen et al. 2000), which incorporates three distinct dimensions (i.e., efficiency, effective ness, and performance) to assess the potential benefits derived by emerging it applications. when adapting the framework to the context of crane lift planning with co help, the definitions of the three dimensions were restated accordingly. efficiency indicated how efficient the functions and features of co help would be to facilitate collaboration in crane lift planning. effectiveness rep resented how effective the functions and features of co help would be to align with the expected or actual crane lift decision making. performance denoted how well co help would perform in delivering the expected results and supporting stakeholders to fulfill crane lift planning. given the relatively few resources existing in the literature for assessing m
# ...

# %% [markdown]
# # **Ranking and Rerank**

# %% [markdown]
# **Ranking**
# This step achieves ranking and filtering the retreived docs
# - Using **Reciprocal Rank Fusion algorithm**

# %%
# The EnsembleRetriever takes a list of retrievers as input and ensemble the results of their get_relevant_documents() methods and
# rerank the results based on the Reciprocal Rank Fusion algorithm.
ensemble_retriever = EnsembleRetriever(
    retrievers=[bm25_retreiver, all_mini_multi_retreiver, multi_qa_mini_multi_retreiver],
    weights=[0.4, 0.3, 0.3] # need to play around these weights
)

# %%
# testing
query = "What is the definition and purpose of Microcode Instruction Cache (MiC) in the context of CPU architecture? Please provide detailed information about its functionality, advantages, and potential applications. If possible, consider providing specific examples or use cases to illustrate its significance."
docs = ensemble_retriever.invoke(query)
print("Ensemble Relevant Docs to process:", len(docs))
print(docs[:1])
# Out:
# Ensemble Relevant Docs to process: 6
# ...

# %% [markdown]
# **Rerank**

# %% [markdown]
# This step achives **Document Relevance**:
# - 信息一致性: Using **LOTR (Merger Retriever)** to combine the results of multiple retrievers with different embedding, rank the results of the different retrievers, which can help to ensure that the most relevant documents are returned first and reduce the risk of bias.
# - 消重: Remove redundant results from the merged retrievers.
# - 信息多样性: Pick a representative sample of documents from the merged retrievers.
#
# Methods:
# - Using DocumentCompressorPipeline to remove redundance then select the representative docs from each clusters
# - Or use BAAI/bge-reranker-v2-m3 directly

# %%
# # Remove redundant results from the merged retrievers, remove redundant results from both retrievers using yet another embedding.
# filter = EmbeddingsRedundantFilter(embeddings=all_mpnet)
# pipeline = DocumentCompressorPipeline(transformers=[filter])
# compression_retrever = ContextualCompressionRetriever(base_compressor=pipeline, base_retriever=lotr)

# %%
# Pick a representative sample of documents from the merged retrievers.
# The result document will be ordered/grouped by clusters.

# %%
# Get relevance scores (higher scores indicate more relevance)
from FlagEmbedding import FlagReranker
reranker = FlagReranker('BAAI/bge-reranker-v2-m3', use_fp16=True) # Setting use_fp16 to True speeds up computation with a slight performance degradation

doc_list = []

# You can map the scores into 0-1 by set "normalize=True", which will apply sigmoid function to the score
scores = reranker.compute_score([['what is panda?', 'hi'], ['what is panda?', 'The giant panda (Ailuropoda melanoleuca), sometimes called a panda bear or simply panda, is a bear species endemic to China.']], normalize=True)
print(scores) # [0.00027803096387751553, 0.9948403768236574]

# %% [markdown]
# **Compression**

# %%
# LLMLingua Document Compressor

# %% [markdown]
# **Functions for retrieved images displayed**

# %%
import io
import re

from IPython.display import HTML, display
from langchain_core.runnables import RunnableLambda, RunnablePassthrough
from PIL import Image


def plt_img_base64(img_base64):
    """Disply base64 encoded string as image"""
    # Create an HTML img tag with the base64 string as the source
    image_html = f'<img src="data:image/jpeg;base64,{img_base64}" />'
    # Display the image by rendering the HTML
    display(HTML(image_html))


def looks_like_base64(sb):
    """Check if the string looks like base64"""
    return re.match("^[A-Za-z0-9+/]+[=]{0,2}$", sb) is not None


def is_image_data(b64data):
    """
    Check if the base64 data is an image by looking at the start of the data
    """
    image_signatures = {
        b"\xff\xd8\xff": "jpg",
        b"\x89\x50\x4e\x47\x0d\x0a\x1a\x0a": "png",
        b"\x47\x49\x46\x38": "gif",
        b"\x52\x49\x46\x46": "webp",
    }
    try:
        header = base64.b64decode(b64data)[:8]  # Decode and get the first 8 bytes
        for sig, format in image_signatures.items():
            if header.startswith(sig):
                return True
        return False
    except Exception:
        return False


def resize_base64_image(base64_string, size=(128, 128)):
    """
    Resize an image encoded as a Base64 string
    """
    # Decode the Base64 string
    img_data = base64.b64decode(base64_string)
    img = Image.open(io.BytesIO(img_data))

    # Resize the image
    resized_img = img.resize(size, Image.LANCZOS)

    # Save the resized image to a bytes buffer
    buffered = io.BytesIO()
    resized_img.save(buffered, format=img.format)

    # Encode the resized image to Base64
    return base64.b64encode(buffered.getvalue()).decode("utf-8")


def split_image_text_types(docs):
    """
    Split base64-encoded images and texts
    """
    b64_images = []
    texts = []
    for doc in docs:
        # Check if the document is of type Document and extract page_content if so
        if isinstance(doc, Document):
            doc = doc.page_content
        if looks_like_base64(doc) and is_image_data(doc):
            doc = resize_base64_image(doc, size=(1300, 600))
            b64_images.append(doc)
        else:
            texts.append(doc)
    return {"image": b64_images, "text": texts}

# %%
retrive_data = split_image_text_types(docs)

for img in retrive_data['image']:
  plt_img_base64(img)

# %% [markdown]
# # **RAG Pipeline**

# %%
def img_prompt_func(data_dict):
    """
    Join the context into a single string
    """
    formatted_texts = "\n".join(data_dict["context"]["text"])
    messages = []

    # Adding image(s) to the messages if present
    if data_dict["context"]["image"]:
        for image in data_dict["context"]["image"]:
            image_message = {
                "type": "image_url",
                "image_url": f"data:image/jpeg;base64,{image}",  # Ensure it's a string
            }
            messages.append(image_message)

    # Adding the text for analysis
    text_message = {
        "type": "text",
        "text": (
            "You are an assistant.\n"
            "You will be given a mixed of text, tables, and image(s) usually of charts or graphs.\n"
            "Use this information to provide investment advice related to the user question. \n"
            f"User-provided question: {data_dict['question']}\n\n"
            "Text and / or tables:\n"
            f"{formatted_texts}"
        ),
    }
    messages.append(text_message)
    return [HumanMessage(content=messages)]

def multi_modal_rag_chain(retriever):
    """
    Multi-modal RAG chain
    """

    # Multi-modal LLM
    model = ChatOllama(model="bakllava")

    # RAG pipeline
    chain = (
        {
            "context": retriever | RunnableLambda(split_image_text_types),
            "question": RunnablePassthrough(),
        }
        | RunnableLambda(img_prompt_func)
        | model
        | StrOutputParser()
    )

    return chain


chain_multimodal_rag = multi_modal_rag_chain(retriever_multi_vector_img)

# %%
chain_multimodal_rag.invoke(query)
# Out:
# "\nAs an AI, I'm not able to see the image or tables directly. However, based on the text provided, I can infer that this paper might be related to a computer system called micrane, which could potentially have applications in finance and investing. The paper appears to include expert interviews, literature reviews, and performance criteria, which suggests it could be a research paper or an informational article."
